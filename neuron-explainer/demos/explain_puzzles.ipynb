# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

os.environ["OPENAI_API_KEY"] = open(os.path.join(os.path.expanduser("~"), ".openai_api_key"), "r").read()[:-1]

from neuron_explainer.activations.activation_records import calculate_max_activation
from neuron_explainer.explanations.explainer import TokenActivationPairExplainer, SummaryExplainer, HighlightExplainer, HighlightSummaryExplainer
from neuron_explainer.explanations.prompt_builder import PromptFormat
from neuron_explainer.explanations.puzzles import PUZZLES_BY_NAME


EXPLAINER_MODEL_NAME = "gpt-3.5-turbo"

# %%
## original
# explainer = TokenActivationPairExplainer(
#     model_name=EXPLAINER_MODEL_NAME,
#     prompt_format=PromptFormat.HARMONY_V4,
#     max_concurrent=1,
# )

# for puzzle_name, puzzle in PUZZLES_BY_NAME.items():
#     print(f"{puzzle_name=}")
#     puzzle_answer = puzzle.explanation
#     # Generate an explanation for the puzzle.
#     explanations = await explainer.generate_explanations(
#         all_activation_records=puzzle.activation_records,
#         max_activation=calculate_max_activation(puzzle.activation_records),
#         num_samples=1,
#     )
#     assert len(explanations) == 1
#     model_generated_explanation = explanations[0]
#     print(f"{model_generated_explanation=}")
#     print(f"{puzzle_answer=}\n")

# %%
explainer = HighlightSummaryExplainer(
    model_name=EXPLAINER_MODEL_NAME,
    prompt_format=PromptFormat.HARMONY_V4,
    max_concurrent=1,
)

for puzzle_name, puzzle in PUZZLES_BY_NAME.items():
    print(f"{puzzle_name=}")
    puzzle_answer = puzzle.explanation
    # Generate an explanation for the puzzle.
    explanations = await explainer.generate_explanations(
        all_activation_records=puzzle.activation_records,
        cutoff=1,
        num_samples=1,
    )
    assert len(explanations) == 1
    model_generated_explanation = explanations[0]
    print(f"{model_generated_explanation=}")
    print(f"{puzzle_answer=}\n")
# Out:
# puzzle_name='colors'
# model_generated_explanation='words related to colors.'
# puzzle_answer='words related to colors and nothing else'
#
# puzzle_name='char2'
# model_generated_explanation='names of people. Specifically, the neuron is detecting repeated mentions of the same name within a short span of text.'
# puzzle_answer='the name of the second named character introduced in the passage, excluding the narrator'
#
# puzzle_name='similes'
# model_generated_explanation='similes and metaphors.'
# puzzle_answer='phrases that are similes and nothing else'
#
# puzzle_name='idioms'
# model_generated_explanation='idiomatic expressions containing nature-related words or phrases such as salt, bush, cake, confection, shrubbery, projectile, and hedge.'
# puzzle_answer="the substitution of a key word in a common idiom that isn't the usual choice for that idiom"
#
# puzzle_name='feet'
# model_generated_explanation='verbs related to movement or action.'
# puzzle_answer='words describing motion that uses feet (e.g. "running", "walking"), but not words describing motion that doesn’t use feet (e.g. "flying", "hovering")'
#
# puzzle_name='years'
# model_generated_explanation='years or numbers with a specific pattern/structure (e.g. 4-digit numbers with the first two digits being "19" or "20" followed by two other digits).'
# puzzle_answer='historically inaccurate numerical years in the passage and nothing else'
#
# puzzle_name='math'
# model_generated_explanation='numerical values in text and solve mathematical problems.'
# puzzle_answer='incorrect answers in grade school math problems'
#
# puzzle_name='complexity'
# model_generated_explanation='terms related to algorithm complexity and efficiency such as big O notation, polynomial time, NP-hard, etc.'
# puzzle_answer='technical phrases related to computational complexity theory'
#
# puzzle_name='an'
# model_generated_explanation="words related to measurements, such as 'miles', 'hour' and 'almost' in some cases."
# puzzle_answer='positions in the sentence where the next word is likely to be "an"'
#
# puzzle_name='time'
# model_generated_explanation='words indicating the passage of time, such as "time," "weeks," "months," and "years."'
# puzzle_answer='time phrases proceeded by the word "in"'
#
# puzzle_name='stop'
# model_generated_explanation='words related to action cessation or prevention.'
# puzzle_answer='language related to something being stopped, prevented, or halted, but only when negated'
#
# puzzle_name='of'
# model_generated_explanation='possessive pronouns and articles (e.g. my, your, the).'
# puzzle_answer='positions in the passage following the word "of"'
#
# puzzle_name='million'
# model_generated_explanation='numbers with six or more digits.'
# puzzle_answer='numbers greater than one million and nothing else'
#
# puzzle_name='people'
# model_generated_explanation='numerical values, particularly related to quantities of people, objects, or measurements.'
# puzzle_answer='numbers if and only if they refer to a number of people'
#
# puzzle_name='python'
# model_generated_explanation="less than signs ('<') used in different contexts."
# puzzle_answer='the character "<" if it occurs in the context of programming but not HTML or math'
#
# puzzle_name='html'
# model_generated_explanation='symbols used in programming and code structure.'
# puzzle_answer='the character "<" if it occurs in the context of HTML but not programming or math'
#
# puzzle_name='int'
# model_generated_explanation='variables and indexing operations in programming code.'
# puzzle_answer='integer variables in C programs'
#
# puzzle_name='death'
# model_generated_explanation='words related to death or dying, specifically verbs that describe the process of dying.'
# puzzle_answer='phrases in a passage that indicate a character has died'
#
# puzzle_name='motivation'
# model_generated_explanation='verbs related to personal ambitions and desires, as well as phrases related to determination and perseverance.'
# puzzle_answer="phrases indicating a character's motivation"
