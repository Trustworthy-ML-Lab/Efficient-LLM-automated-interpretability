# %%
import pandas as pd
import utils
from neuron_explainer.activations.activations import ActivationRecordSliceParams, load_neuron

# %%
EXPLAINER_MODEL = "gpt-3.5-turbo"
INPUT_PATH = "inputs/test_neurons.csv"

neuron_df = pd.read_csv(INPUT_PATH)
neuron_df
# Out:
#    layer  neuron     score                                        explanation
# 0      0     286  0.663509                       words related to comparison.
# 1     10    1838  0.676886   phrases describing positions or situations in...
# 2     20     193  0.455764  verbs indicating questioning or challenging be...
# 3     30    1685  0.537097   expressions of gratitude and agreeing to rece...
# 4     40     431  0.365750   numbers related to time, dates, and measureme...

# %%
modes = ["Original", "Summary", "Highlight", "HighlightSummary", "AVHS"]
new_results = {"layer":[], "neuron":[], "explainer":[], "NeuronViewer":[]}
for mode in modes:
    new_results[mode] = []

for i, row in neuron_df.iterrows():
    layer = row["layer"]
    neuron = row["neuron"]
    new_results["layer"].append(layer)
    new_results["neuron"].append(neuron)
    new_results["NeuronViewer"].append(row["explanation"])
    new_results["explainer"].append(EXPLAINER_MODEL)
    neuron_record = load_neuron(layer, neuron)
    
    for mode in modes:
        new_results[mode].append(await utils.get_explanation(mode=mode, neuron_record=neuron_record, explainer_model=EXPLAINER_MODEL))

new_df = pd.DataFrame(new_results)
new_df
# Out:
#    layer  neuron      explainer  \
# 0      0     286  gpt-3.5-turbo
# 1     10    1838  gpt-3.5-turbo
# 2     20     193  gpt-3.5-turbo
# 3     30    1685  gpt-3.5-turbo
# 4     40     431  gpt-3.5-turbo
#
#                                         NeuronViewer  \
# 0                       words related to comparison.
# 1   phrases describing positions or situations in...
# 2  verbs indicating questioning or challenging be...
# 3   expressions of gratitude and agreeing to rece...
# 4   numbers related to time, dates, and measureme...
#
#                                             Original  \
# 0  comparisons between different entities or situ...
# 1  phrases related to personal situations or expe...
# 2  phrases related to calling out or criticizing ...
# 3  phrases related to newsletter subscriptions an...
# 4   timestamps and time-related information in text.
#
#                                              Summary  \
# 0  words or phrases that indicate a comparison or...
# 1  reflexive pronouns and their variations, such ...
# 2  words related to expressing criticism or quest...
# 3  words and phrases related to subscribing to ne...
# 4              numbers and time-related information.
#
#                                            Highlight  \
# 0  words related to comparisons or contrasts betw...
# 1  instances of reflexive pronouns (e.g. "themsel...
# 2  tokens related to expressing or questioning op...
# 3  phrases related to expressing gratitude or tha...
# 4  time-related information, such as timestamps o...
#
#                                     HighlightSummary  \
# 0       words related to comparisons or contrasting.
# 1  pronouns or words related to self or individua...
# 2  words related to expressing disagreement, crit...
# 3  words and phrases related to expressing gratit...
# 4  time-related information, including hours, min...
#
#                                                 AVHS
# 0  words related to comparing or contrasting two ...
# 1  pronouns or words related to self-identificati...
# 2  instances where someone is being called out or...
# 3  tokens related to newsletter sign-up and subsc...
# 4   information related to dates, times, and events.

# %%
new_df.to_csv("test_results/"+INPUT_PATH.split("/")[-1].split(".")[0] + "_results.csv")
