# %%
import pandas as pd
import utils
from neuron_explainer.explanations.puzzles import PUZZLES_BY_NAME

# %%
EXPLAINER_MODEL_NAME = "gpt-3.5-turbo"

# %%
modes = ["Original", "Summary", "Highlight", "HighlightSummary", "AVHS"]
puzzle_results = {"puzzle_name":[], "answer":[]}

for mode in modes:
    puzzle_results[mode] = []

for puzzle_name, puzzle in PUZZLES_BY_NAME.items():
    puzzle_results["puzzle_name"].append(puzzle_name)
    puzzle_answer = puzzle.explanation
    puzzle_results["answer"].append(puzzle_answer)
    for mode in modes:
        puzzle_results[mode].append(await utils.get_puzzle_explanation(mode=mode, explainer_model=EXPLAINER_MODEL_NAME, 
                                                                       puzzle_activation_record=puzzle.activation_records))
   
puzzle_df = pd.DataFrame(puzzle_results)
puzzle_df
# Out:
#    puzzle_name                                             answer  \
# 0       colors           words related to colors and nothing else
# 1        char2  the name of the second named character introdu...
# 2      similes          phrases that are similes and nothing else
# 3       idioms  the substitution of a key word in a common idi...
# 4         feet  words describing motion that uses feet (e.g. "...
# 5        years  historically inaccurate numerical years in the...
# 6         math    incorrect answers in grade school math problems
# 7   complexity  technical phrases related to computational com...
# 8           an  positions in the sentence where the next word ...
# 9         time            time phrases proceeded by the word "in"
# 10        stop  language related to something being stopped, p...
# 11          of   positions in the passage following the word "of"
# 12     million  numbers greater than one million and nothing else
# 13      people  numbers if and only if they refer to a number ...
# 14      python  the character "<" if it occurs in the context ...
# 15        html  the character "<" if it occurs in the context ...
# 16         int                    integer variables in C programs
# 17       death  phrases in a passage that indicate a character...
# 18  motivation        phrases indicating a character's motivation
#
#                                              Original  \
# 0                     colors and color-related words.
# 1                     names of characters in a story.
# 2   comparisons using similes, where one thing is ...
# 3   idioms or phrases that involve food or substan...
# 4   action verbs related to physical movement or a...
# 5                         years or historical events.
# 6   numbers that are answers to mathematical quest...
# 7   terminology and concepts related to algorithmi...
# 8            phrases related to action or activities.
# 9             phrases related to the passage of time.
# 10  words related to actions or states of stopping...
# 11  personal pronouns followed by possessive adjec...
# 12  large numerical values representing quantities...
# 13          numbers indicating quantities or amounts.
# 14  angle brackets (less than and greater than sym...
# 15                       programming code and syntax.
# 16  code snippets related to arithmetic operations...
# 17  words and phrases related to dramatic events a...
# 18  narratives or descriptions of personal pursuit...
#
#                                               Summary  \
# 0                                  colors and shades.
# 1    names of characters in a story or text excerpts.
# 2             comparisons using similes or metaphors.
# 3   words related to different types of plants or ...
# 4    words related to physical actions and movements.
# 5   years or numbers that represent historical eve...
# 6   numbers, specifically quantities and calculati...
# 7   terms and concepts related to time complexity ...
# 8   words related to measurement, quantity, or com...
# 9     phrases related to duration or passage of time.
# 10  verbs related to actions of stopping or preven...
# 11                  possessive pronouns and articles.
# 12           numbers with multiple zeros (0) in them.
# 13     numeric values or words related to quantities.
# 14  symbols or characters such as "<" in programmi...
# 15  symbols and elements related to programming la...
# 16  variables and their assignments/usage in code ...
# 17   phrases related to endings, death, and survival.
# 18  verbs and nouns related to personal goals, asp...
#
#                                             Highlight  \
# 0                      colors or color-related words.
# 1   tokens representing names of people or charact...
# 2   similes or comparisons using the words 'like' ...
# 3   idiomatic expressions or phrases related to ca...
# 4   words/actions related to physical movement or ...
# 5                dates or years in historical events.
# 6   mathematical calculations and numerical values...
# 7   terms and notations related to algorithm compl...
# 8   phrases related to quantifying or measuring qu...
# 9   phrases or expressions related to the passage ...
# 10  actions or statements related to ceasing or no...
# 11  phrases where a possessive pronoun (your, my) ...
# 12                                numbers and digits.
# 13                    numerical quantities or counts.
# 14          comparison operators such as `<` and `>`.
# 15  code snippets or specific syntax patterns from...
# 16  tokens related to computer programming, includ...
# 17  phrases or words related to the end of life or...
# 18  verbs or phrases indicating personal goals, as...
#
#                                      HighlightSummary  \
# 0          colors or color-related words and phrases.
# 1       names of characters in narratives or stories.
# 2   comparisons using "like" or similes, as well a...
# 3   phrases or words related to idiomatic expressi...
# 4   words related to various types of physical mov...
# 5   numbers related to specific historical events ...
# 6   numerical values in text, specifically those t...
# 7   terms related to computational complexity and ...
# 8   words related to actions or verbs, particularl...
# 9    temporal references or time-related expressions.
# 10  words related to the action of stopping or hal...
# 11                possessive pronouns or determiners.
# 12  numbers or numerical values that are mentioned...
# 13                    numerical values or quantities.
# 14  the less than symbol "<" commonly used in prog...
# 15                       code snippets and HTML tags.
# 16  individual variables and their manipulations w...
# 17  words and phrases related to endings, death, a...
# 18  verbs and phrases related to personal goals, a...
#
#                                                  AVHS
# 0               colors and color-related words/terms.
# 1                         names of characters/people.
# 2   similes and comparisons using the word "like" ...
# 3   idiomatic expressions related to plants, food,...
# 4          action verbs related to physical movement.
# 5               dates or years mentioned in the text.
# 6   numbers or numerical values mentioned in the t...
# 7   terms and concepts related to algorithm comple...
# 8             words related to actions or activities.
# 9   expressions related to time duration or passag...
# 10  verbs or phrases related to ceasing or discont...
# 11                possessive pronouns or determiners.
# 12      numeric values in the thousands and millions.
# 13                              numerical quantities.
# 14  less than (<) symbols in code or mathematical ...
# 15  HTML and programming code related tokens such ...
# 16  syntax elements and variables used in programm...
# 17  words related to the end of life or imminent d...
# 18  verbs related to personal goals, aspirations, ...

# %%
puzzle_df.to_csv("test_results/puzzle_results.csv")
